# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statistics
import warnings
warnings.simplefilter('ignore')

# %% [markdown]
# ## Rodentia: Species Distribution Analysis

# %%
rodent_rm_df = pd.DataFrame(pd.read_csv('1kmerized.Rodentia.csv')['genus name'].value_counts()[:30])
rodent_rm_df.columns = ['species count']
rodent_rm_df.insert(0, 'species name', rodent_rm_df.index, True)
rodent_rm_df.index = np.arange(len(rodent_rm_df))
rodent_rm_df
# Out:
#     species name  species count
# 0        Praomys             65
# 1         Rattus             58
# 2     Hylomyscus             45
# 3     Cricetulus             40
# 4       Apodemus             39
# 5       Ctenomys             36
# 6       Mastomys             32
# 7     Niviventer             24
# 8         Neodon             22
# 9         Myodes             17
# 10           Mus             16
# 11     Allactaga             13
# 12      Microtus             11
# 13     Heimyscus              8
# 14      Phodopus              8
# 15      Eospalax              6
# 16     Bandicota              5
# 17  Lasiopodomys              5
# 18      Meriones              4
# 19         Dipus              4
# 20       Colomys              3
# 21    Eothenomys              3
# 22      Micromys              3
# 23      Juliomys              2
# 24   Leopoldamys              2
# 25      Caryomys              2
# 26  Euryoryzomys              2
# 27  Mesocricetus              1
# 28      Pteromys              1
# 29     Cuniculus              1

# %%
rodent_org_df = pd.DataFrame(pd.read_csv('../raw_data/Rodentia.csv')['genus_name'].value_counts())
rodent_org_df.columns = ['species count']
rodent_org_df.insert(0, 'species name', rodent_org_df.index, True)
rodent_org_df.index = np.arange(len(rodent_org_df))
rodent_org_df
# Out:
#      species name  species count
# 0      Peromyscus            379
# 1          Liomys            286
# 2          Rattus            281
# 3        Oryzomys            263
# 4      Proechimys            188
# ..            ...            ...
# 126      Trinomys              1
# 127  Chiropodomys              1
# 128       Tamiops              1
# 129      Isothrix              1
# 130     Petinomys              1
#
# [131 rows x 2 columns]

# %%
joined_rodent = pd.DataFrame(pd.merge(rodent_rm_df, rodent_org_df, on='species name'))
joined_rodent
# Out:
#     species name  species count_x  species count_y
# 0        Praomys               65              159
# 1         Rattus               58              281
# 2     Hylomyscus               45              105
# 3     Cricetulus               40               45
# 4       Apodemus               39              106
# 5       Ctenomys               36               66
# 6       Mastomys               32              153
# 7     Niviventer               24               86
# 8         Neodon               22               31
# 9         Myodes               17              102
# 10           Mus               16               69
# 11     Allactaga               13               18
# 12      Microtus               11               74
# 13     Heimyscus                8               15
# 14      Phodopus                8               15
# 15      Eospalax                6               13
# 16     Bandicota                5                7
# 17  Lasiopodomys                5               10
# 18      Meriones                4                7
# 19         Dipus                4                5
# 20       Colomys                3                6
# 21    Eothenomys                3               49
# 22      Micromys                3                3
# 23      Juliomys                2                2
# 24   Leopoldamys                2               26
# 25      Caryomys                2                2
# 26  Euryoryzomys                2               18
# 27  Mesocricetus                1                9
# 28      Pteromys                1                2
# 29     Cuniculus                1               15

# %%
rodent_ratio = joined_rodent[['species count_x']].div(joined_rodent['species count_y'], axis=0).apply(lambda x: round(x*100, 2))
rodent_ratio.columns = ['removed %']
rodent_final = pd.concat([joined_rodent, rodent_ratio], axis=1).sort_values(by='removed %', ascending=False)
rodent_final
# Out:
#     species name  species count_x  species count_y  removed %
# 23      Juliomys                2                2     100.00
# 22      Micromys                3                3     100.00
# 25      Caryomys                2                2     100.00
# 3     Cricetulus               40               45      88.89
# 19         Dipus                4                5      80.00
# 11     Allactaga               13               18      72.22
# 16     Bandicota                5                7      71.43
# 8         Neodon               22               31      70.97
# 18      Meriones                4                7      57.14
# 5       Ctenomys               36               66      54.55
# 13     Heimyscus                8               15      53.33
# 14      Phodopus                8               15      53.33
# 17  Lasiopodomys                5               10      50.00
# 20       Colomys                3                6      50.00
# 28      Pteromys                1                2      50.00
# 15      Eospalax                6               13      46.15
# 2     Hylomyscus               45              105      42.86
# 0        Praomys               65              159      40.88
# 4       Apodemus               39              106      36.79
# 7     Niviventer               24               86      27.91
# 10           Mus               16               69      23.19
# 6       Mastomys               32              153      20.92
# 1         Rattus               58              281      20.64
# 9         Myodes               17              102      16.67
# 12      Microtus               11               74      14.86
# 26  Euryoryzomys                2               18      11.11
# 27  Mesocricetus                1                9      11.11
# 24   Leopoldamys                2               26       7.69
# 29     Cuniculus                1               15       6.67
# 21    Eothenomys                3               49       6.12

# %%
rodent_final.plot(x='species name', y=['removed %'], kind='bar', figsize=(8,6), title='Removed Species % - Rodentia')

# %%
rodent_org_df.plot(kind='kde', title='Rodentia Species Frequency Distribution - Original Data')

# %%
rodent_after_pp = pd.DataFrame(pd.read_csv('../datasets/Rodentia.Cleaned.k1.csv')['genus_name'].value_counts())
rodent_after_pp.columns = ['species count']
rodent_after_pp.plot(kind='kde', title='Rodentia Species Frequency Distribution - Processed Data')

# %% [markdown]
# ## Aves: Species Distribution Analysis

# %%
aves_rm_df = pd.DataFrame(pd.read_csv('1kmerized.Aves.csv')['genus name'].value_counts()[:30])
aves_rm_df.columns = ['species count']
aves_rm_df.insert(0, 'species name', aves_rm_df.index, True)
aves_rm_df.index = np.arange(len(aves_rm_df))
aves_rm_df
# Out:
#     species name  species count
# 0         Turdus             16
# 1        Tangara             13
# 2       Emberiza             12
# 3       Euphonia             11
# 4      Cyanistes             11
# 5           Anas              9
# 6         Corvus              9
# 7   Basileuterus              9
# 8   Pachyramphus              8
# 9         Sylvia              8
# 10    Sporophila              8
# 11  Phylloscopus              8
# 12         Larus              8
# 13   Patagioenas              7
# 14      Ficedula              7
# 15    Pycnonotus              7
# 16     Carduelis              7
# 17    Cercomacra              7
# 18   Dendrocopos              7
# 19        Celeus              7
# 20      Aratinga              7
# 21     Myrmeciza              6
# 22  Thamnophilus              6
# 23     Accipiter              6
# 24       Poecile              6
# 25      Garrulax              6
# 26   Buteogallus              5
# 27        Jacana              5
# 28        Anthus              5
# 29  Myrmotherula              5

# %%
aves_org_df = pd.DataFrame(pd.read_csv('../raw_data/Aves.csv')['genus_name'].value_counts())
aves_org_df.columns = ['species count']
aves_org_df.insert(0, 'species name', aves_org_df.index, True)
aves_org_df.index = np.arange(len(aves_org_df))
aves_org_df
# Out:
#       species name  species count
# 0           Gallus             84
# 1           Turdus             82
# 2             Anas             66
# 3       Pycnonotus             56
# 4        Carduelis             56
# ...            ...            ...
# 998      Urocolius              1
# 999         Pastor              1
# 1000    Donacobius              1
# 1001  Centrocercus              1
# 1002    Premnoplex              1
#
# [1003 rows x 2 columns]

# %%
joined_aves = pd.DataFrame(pd.merge(aves_rm_df, aves_org_df, on='species name'))
joined_aves
# Out:
#     species name  species count_x  species count_y
# 0         Turdus               16               82
# 1        Tangara               13               14
# 2       Emberiza               12               49
# 3       Euphonia               11               20
# 4      Cyanistes               11               17
# 5           Anas                9               66
# 6         Corvus                9               35
# 7   Basileuterus                9               19
# 8   Pachyramphus                8               10
# 9         Sylvia                8               25
# 10    Sporophila                8               27
# 11  Phylloscopus                8               34
# 12         Larus                8               42
# 13   Patagioenas                7               10
# 14      Ficedula                7               35
# 15    Pycnonotus                7               56
# 16     Carduelis                7               56
# 17    Cercomacra                7                8
# 18   Dendrocopos                7               23
# 19        Celeus                7               11
# 20      Aratinga                7               11
# 21     Myrmeciza                6                6
# 22  Thamnophilus                6               12
# 23     Accipiter                6               46
# 24       Poecile                6               28
# 25      Garrulax                6               19
# 26   Buteogallus                5                6
# 27        Jacana                5                6
# 28        Anthus                5               44
# 29  Myrmotherula                5               33

# %%
aves_ratio = joined_aves[['species count_x']].div(joined_aves['species count_y'], axis=0).apply(lambda x: round(x*100, 2))
aves_ratio.columns = ['removed %']
aves_final = pd.concat([joined_aves, aves_ratio], axis=1).sort_values(by='removed %', ascending=False)
aves_final
# Out:
#     species name  species count_x  species count_y  removed %
# 21     Myrmeciza                6                6     100.00
# 1        Tangara               13               14      92.86
# 17    Cercomacra                7                8      87.50
# 27        Jacana                5                6      83.33
# 26   Buteogallus                5                6      83.33
# 8   Pachyramphus                8               10      80.00
# 13   Patagioenas                7               10      70.00
# 4      Cyanistes               11               17      64.71
# 20      Aratinga                7               11      63.64
# 19        Celeus                7               11      63.64
# 3       Euphonia               11               20      55.00
# 22  Thamnophilus                6               12      50.00
# 7   Basileuterus                9               19      47.37
# 9         Sylvia                8               25      32.00
# 25      Garrulax                6               19      31.58
# 18   Dendrocopos                7               23      30.43
# 10    Sporophila                8               27      29.63
# 6         Corvus                9               35      25.71
# 2       Emberiza               12               49      24.49
# 11  Phylloscopus                8               34      23.53
# 24       Poecile                6               28      21.43
# 14      Ficedula                7               35      20.00
# 0         Turdus               16               82      19.51
# 12         Larus                8               42      19.05
# 29  Myrmotherula                5               33      15.15
# 5           Anas                9               66      13.64
# 23     Accipiter                6               46      13.04
# 16     Carduelis                7               56      12.50
# 15    Pycnonotus                7               56      12.50
# 28        Anthus                5               44      11.36

# %%
aves_final.plot(x='species name', y=['removed %'], kind='bar', figsize=(8,6), title='Removed Species % - Aves')

# %%
aves_org_df.plot(kind='kde', title='Aves Species Frequency Distribution - Original Data')

# %%
aves_after_pp = pd.DataFrame(pd.read_csv('../datasets/Aves.Cleaned.k1.csv')['genus_name'].value_counts())
aves_after_pp.columns = ['species count']
aves_after_pp.plot(kind='kde', title='Aves Species Frequency Distribution - Processed Data')

# %%
chirop_rm_df = pd.DataFrame(pd.read_csv('1kmerized.Chiroptera.csv')['genus name'].value_counts())
chirop_rm_df.columns = ['species count']
chirop_rm_df.insert(0, 'species name', chirop_rm_df.index, True)
chirop_rm_df.index = np.arange(len(chirop_rm_df))
chirop_rm_df
# Out:
#       species name  species count
# 0       Pteronotus              3
# 1         Lasiurus              2
# 2  Rhynchonycteris              2
# 3    Micronycteris              1
# 4     Pipistrellus              1
# 5           Myotis              1

# %%
chirop_org_df = pd.DataFrame(pd.read_csv('../raw_data/Chiroptera.csv')['genus_name'].value_counts())
chirop_org_df.columns = ['species count']
chirop_org_df.insert(0, 'species name', chirop_org_df.index, True)
chirop_org_df.index = np.arange(len(chirop_org_df))
chirop_org_df
# Out:
#      species name  species count
# 0        Artibeus            967
# 1        Carollia            470
# 2          Myotis            269
# 3     Rhinolophus            243
# 4        Sturnira            157
# ..            ...            ...
# 117     Cyttarops              1
# 118   Barbastella              1
# 119  Hylonycteris              1
# 120   Saccolaimus              1
# 121       Promops              1
#
# [122 rows x 2 columns]

# %%
joined_chirop = pd.DataFrame(pd.merge(chirop_rm_df, chirop_org_df, on='species name'))
joined_chirop
# Out:
#       species name  species count_x  species count_y
# 0       Pteronotus                3              147
# 1         Lasiurus                2               45
# 2  Rhynchonycteris                2               29
# 3    Micronycteris                1               21
# 4     Pipistrellus                1               89
# 5           Myotis                1              269

# %%
chirop_ratio = joined_chirop[['species count_x']].div(joined_chirop['species count_y'], axis=0).apply(lambda x: round(x*100, 2))
chirop_ratio.columns = ['removed %']
chirop_final = pd.concat([joined_chirop, chirop_ratio], axis=1).sort_values(by='removed %', ascending=False)
chirop_final
# Out:
#       species name  species count_x  species count_y  removed %
# 2  Rhynchonycteris                2               29       6.90
# 3    Micronycteris                1               21       4.76
# 1         Lasiurus                2               45       4.44
# 0       Pteronotus                3              147       2.04
# 4     Pipistrellus                1               89       1.12
# 5           Myotis                1              269       0.37

# %%
chirop_final.plot(x='species name', y=['removed %'], kind='bar', figsize=(8,6), title='Removed Species % - Chiroptera')

# %%
chirop_org_df.plot(kind='kde', title='Chiroptera Species Frequency Distribution - Original Data')

# %%
chirop_after_pp = pd.DataFrame(pd.read_csv('../datasets/Chiroptera.Cleaned.k1.csv')['genus_name'].value_counts())
chirop_after_pp.columns = ['species count']
chirop_after_pp.plot(kind='kde', title='Chiroptera Species Frequency Distribution - Processed Data')

# %% [markdown]
# # K-Samples Anderson-Darling Test

# %%
from scipy.stats import anderson_ksamp

# %%
rodent_removed = np.array(pd.read_csv('1kmerized.Rodentia.csv')['genus name'])
rodent_original = np.array(pd.read_csv('../raw_data/Rodentia.csv')['genus_name'])
ak_test_aves = anderson_ksamp([rodent_removed, rodent_original])
ak_test_aves
# Out:
# Anderson_ksampResult(statistic=56.91253213434344, critical_values=array([0.325, 1.226, 1.961, 2.718, 3.752, 4.592, 6.546]), significance_level=0.001)

# %%
aves_removed = np.array(pd.read_csv('1kmerized.Aves.csv')['genus name'])
aves_original = np.array(pd.read_csv('../raw_data/Aves.csv')['genus_name'])
ak_test_aves = anderson_ksamp([aves_removed, aves_original])
ak_test_aves
# Out:
# Anderson_ksampResult(statistic=-0.17245177435094056, critical_values=array([0.325, 1.226, 1.961, 2.718, 3.752, 4.592, 6.546]), significance_level=0.25)

# %%
chirop_removed = np.array(pd.read_csv('1kmerized.Chiroptera.csv')['genus name'])
chirop_original = np.array(pd.read_csv('../raw_data/Chiroptera.csv')['genus_name'])
ak_test_chirop = anderson_ksamp([chirop_removed, chirop_original])
ak_test_chirop
# Out:
# Anderson_ksampResult(statistic=2.993564819053475, critical_values=array([0.325, 1.226, 1.961, 2.718, 3.752, 4.592, 6.546]), significance_level=0.019587162609212633)
